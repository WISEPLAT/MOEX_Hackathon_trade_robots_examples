# %%
import pandas as pandas

# %%
df = pandas.read_csv('FinalStats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 secid                   ts  put_orders  put_orders_b  \
# 0           0  ABRD  2020-01-03 10:05:00          30            18
# 1           1  AFKS  2020-01-03 10:05:00        1132           633
# 2           2  AFLT  2020-01-03 10:05:00         992           440
# 3           3  AGRO  2020-01-03 10:05:00         624           362
# 4           4  AKRN  2020-01-03 10:05:00         164           117
#
#    put_orders_s  put_vol  put_vol_b  put_vol_s      put_val  ...  cancel_vol  \
# 0            12      403        233        170     518480.0  ...          25
# 1           499    88427      64153      24274  143450996.0  ...       74373
# 2           552   119570      48617      70953  123538069.0  ...       74253
# 3           262    85903      49820      36083   55551908.0  ...       72327
# 4            47     1554       1163        391   11587524.0  ...         769
#
#    cancel_vol_b  cancel_vol_s   cancel_val  cancel_val_b  cancel_val_s  \
# 0             0            25      36875.0           0.0       36875.0
# 1         54883         19490  112685505.0    82792348.0    29893156.0
# 2         18367         55886   76876628.0    18911407.0    57965221.0
# 3         39105         33222   47200062.0    25260105.0    21939957.0
# 4           626           143    3683750.0     2990282.0      693468.0
#
#    put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0     114.800     147.700            NaN        147.500
# 1      16.546      15.368         15.085         15.338
# 2     102.560     103.840        102.960        103.720
# 3     632.700     666.000        646.000        660.400
# 4    4625.000   15879.000       4777.000       4849.000
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20821475 entries, 0 to 20821474
# Data columns (total 25 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   secid            object
#  2   ts               object
#  3   put_orders       int64
#  4   put_orders_b     int64
#  5   put_orders_s     int64
#  6   put_vol          int64
#  7   put_vol_b        int64
#  8   put_vol_s        int64
#  9   put_val          float64
#  10  put_val_b        float64
#  11  put_val_s        float64
#  12  cancel_orders    int64
#  13  cancel_orders_b  int64
#  14  cancel_orders_s  int64
#  15  cancel_vol       int64
#  16  cancel_vol_b     int64
#  17  cancel_vol_s     int64
#  18  cancel_val       float64
#  19  cancel_val_b     float64
#  20  cancel_val_s     float64
#  21  put_vwap_b       float64
#  22  put_vwap_s       float64
#  23  cancel_vwap_b    float64
#  24  cancel_vwap_s    float64
# dtypes: float64(10), int64(13), object(2)
# memory usage: 3.9+ GB

# %%
df.head()
# Out:
#    Unnamed: 0 secid                   ts  put_orders  put_orders_b  \
# 0           0  ABRD  2020-01-03 10:05:00          30            18
# 1           1  AFKS  2020-01-03 10:05:00        1132           633
# 2           2  AFLT  2020-01-03 10:05:00         992           440
# 3           3  AGRO  2020-01-03 10:05:00         624           362
# 4           4  AKRN  2020-01-03 10:05:00         164           117
#
#    put_orders_s  put_vol  put_vol_b  put_vol_s      put_val  ...  cancel_vol  \
# 0            12      403        233        170     518480.0  ...          25
# 1           499    88427      64153      24274  143450996.0  ...       74373
# 2           552   119570      48617      70953  123538069.0  ...       74253
# 3           262    85903      49820      36083   55551908.0  ...       72327
# 4            47     1554       1163        391   11587524.0  ...         769
#
#    cancel_vol_b  cancel_vol_s   cancel_val  cancel_val_b  cancel_val_s  \
# 0             0            25      36875.0           0.0       36875.0
# 1         54883         19490  112685505.0    82792348.0    29893156.0
# 2         18367         55886   76876628.0    18911407.0    57965221.0
# 3         39105         33222   47200062.0    25260105.0    21939957.0
# 4           626           143    3683750.0     2990282.0      693468.0
#
#    put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0     114.800     147.700            NaN        147.500
# 1      16.546      15.368         15.085         15.338
# 2     102.560     103.840        102.960        103.720
# 3     632.700     666.000        646.000        660.400
# 4    4625.000   15879.000       4777.000       4849.000
#
# [5 rows x 25 columns]

# %%
df.drop('Unnamed: 0', axis=1)
# Out:
#           secid                   ts  put_orders  put_orders_b  put_orders_s  \
# 0          ABRD  2020-01-03 10:05:00          30            18            12
# 1          AFKS  2020-01-03 10:05:00        1132           633           499
# 2          AFLT  2020-01-03 10:05:00         992           440           552
# 3          AGRO  2020-01-03 10:05:00         624           362           262
# 4          AKRN  2020-01-03 10:05:00         164           117            47
# ...         ...                  ...         ...           ...           ...
# 20821470   YNDX  2023-11-30 18:40:00       13185          3473          9712
# 20821471   YRSB  2023-11-30 18:40:00          55             4            51
# 20821472  YRSBP  2023-11-30 18:40:00          23            15             8
# 20821473   ZILL  2023-11-30 18:40:00          85             0            85
# 20821474   ZVEZ  2023-11-30 18:40:00         314             3           311
#
#           put_vol  put_vol_b  put_vol_s       put_val    put_val_b  ...  \
# 0             403        233        170  5.184800e+05     267445.0  ...
# 1           88427      64153      24274  1.434510e+08  106146948.0  ...
# 2          119570      48617      70953  1.235381e+08   49863924.0  ...
# 3           85903      49820      36083  5.555191e+07   31519209.0  ...
# 4            1554       1163        391  1.158752e+07    5378990.0  ...
# ...           ...        ...        ...           ...          ...  ...
# 20821470  1267419     258470    1008949  3.227271e+09  654778629.0  ...
# 20821471      209          7        202  2.036940e+05       5626.0  ...
# 20821472      195         85        110  4.859500e+04      21600.0  ...
# 20821473     1934          0       1934  6.555475e+06          0.0  ...
# 20821474     2469          4       2465  2.679500e+04         42.0  ...
#
#           cancel_vol  cancel_vol_b  cancel_vol_s    cancel_val  cancel_val_b  \
# 0                 25             0            25  3.687500e+04           0.0
# 1              74373         54883         19490  1.126855e+08    82792348.0
# 2              74253         18367         55886  7.687663e+07    18911407.0
# 3              72327         39105         33222  4.720006e+07    25260105.0
# 4                769           626           143  3.683750e+06     2990282.0
# ...              ...           ...           ...           ...           ...
# 20821470     1257390        254430       1002960  3.206532e+09   646414136.0
# 20821471         211             2           209  2.072280e+05        1838.0
# 20821472         212           105           107  5.558300e+04       26363.0
# 20821473        1935             2          1933  6.559660e+06        6490.0
# 20821474        2478            13          2465  2.688800e+04         122.0
#
#           cancel_val_s  put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0              36875.0     114.800     147.700            NaN        147.500
# 1           29893156.0      16.546      15.368         15.085         15.338
# 2           57965221.0     102.560     103.840        102.960        103.720
# 3           21939957.0     632.700     666.000        646.000        660.400
# 4             693468.0    4625.000   15879.000       4777.000       4849.000
# ...                ...         ...         ...            ...            ...
# 20821470   646414136.0    2533.300    2549.700       2540.600       2552.600
# 20821471        1838.0      80.400      98.100         91.900         98.300
# 20821472       26363.0      25.400      24.500         25.100         27.300
# 20821473        6490.0         NaN    3389.600       3245.000       3390.200
# 20821474         122.0       0.011       0.011          0.009          0.011
#
# [20821475 rows x 24 columns]

# %%
df.head()
# Out:
#    Unnamed: 0 secid                   ts  put_orders  put_orders_b  \
# 0           0  ABRD  2020-01-03 10:05:00          30            18
# 1           1  AFKS  2020-01-03 10:05:00        1132           633
# 2           2  AFLT  2020-01-03 10:05:00         992           440
# 3           3  AGRO  2020-01-03 10:05:00         624           362
# 4           4  AKRN  2020-01-03 10:05:00         164           117
#
#    put_orders_s  put_vol  put_vol_b  put_vol_s      put_val  ...  cancel_vol  \
# 0            12      403        233        170     518480.0  ...          25
# 1           499    88427      64153      24274  143450996.0  ...       74373
# 2           552   119570      48617      70953  123538069.0  ...       74253
# 3           262    85903      49820      36083   55551908.0  ...       72327
# 4            47     1554       1163        391   11587524.0  ...         769
#
#    cancel_vol_b  cancel_vol_s   cancel_val  cancel_val_b  cancel_val_s  \
# 0             0            25      36875.0           0.0       36875.0
# 1         54883         19490  112685505.0    82792348.0    29893156.0
# 2         18367         55886   76876628.0    18911407.0    57965221.0
# 3         39105         33222   47200062.0    25260105.0    21939957.0
# 4           626           143    3683750.0     2990282.0      693468.0
#
#    put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0     114.800     147.700            NaN        147.500
# 1      16.546      15.368         15.085         15.338
# 2     102.560     103.840        102.960        103.720
# 3     632.700     666.000        646.000        660.400
# 4    4625.000   15879.000       4777.000       4849.000
#
# [5 rows x 25 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#   secid                   ts  put_orders  put_orders_b  put_orders_s  put_vol  \
# 0  ABRD  2020-01-03 10:05:00          30            18            12      403
# 1  AFKS  2020-01-03 10:05:00        1132           633           499    88427
# 2  AFLT  2020-01-03 10:05:00         992           440           552   119570
# 3  AGRO  2020-01-03 10:05:00         624           362           262    85903
# 4  AKRN  2020-01-03 10:05:00         164           117            47     1554
#
#    put_vol_b  put_vol_s      put_val    put_val_b  ...  cancel_vol  \
# 0        233        170     518480.0     267445.0  ...          25
# 1      64153      24274  143450996.0  106146948.0  ...       74373
# 2      48617      70953  123538069.0   49863924.0  ...       74253
# 3      49820      36083   55551908.0   31519209.0  ...       72327
# 4       1163        391   11587524.0    5378990.0  ...         769
#
#    cancel_vol_b  cancel_vol_s   cancel_val  cancel_val_b  cancel_val_s  \
# 0             0            25      36875.0           0.0       36875.0
# 1         54883         19490  112685505.0    82792348.0    29893156.0
# 2         18367         55886   76876628.0    18911407.0    57965221.0
# 3         39105         33222   47200062.0    25260105.0    21939957.0
# 4           626           143    3683750.0     2990282.0      693468.0
#
#    put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0     114.800     147.700            NaN        147.500
# 1      16.546      15.368         15.085         15.338
# 2     102.560     103.840        102.960        103.720
# 3     632.700     666.000        646.000        660.400
# 4    4625.000   15879.000       4777.000       4849.000
#
# [5 rows x 24 columns]

# %%
df.isnull()
# Out:
#           secid     ts  put_orders  put_orders_b  put_orders_s  put_vol  \
# 0         False  False       False         False         False    False
# 1         False  False       False         False         False    False
# 2         False  False       False         False         False    False
# 3         False  False       False         False         False    False
# 4         False  False       False         False         False    False
# ...         ...    ...         ...           ...           ...      ...
# 20821470  False  False       False         False         False    False
# 20821471  False  False       False         False         False    False
# 20821472  False  False       False         False         False    False
# 20821473  False  False       False         False         False    False
# 20821474  False  False       False         False         False    False
#
#           put_vol_b  put_vol_s  put_val  put_val_b  ...  cancel_vol  \
# 0             False      False    False      False  ...       False
# 1             False      False    False      False  ...       False
# 2             False      False    False      False  ...       False
# 3             False      False    False      False  ...       False
# 4             False      False    False      False  ...       False
# ...             ...        ...      ...        ...  ...         ...
# 20821470      False      False    False      False  ...       False
# 20821471      False      False    False      False  ...       False
# 20821472      False      False    False      False  ...       False
# 20821473      False      False    False      False  ...       False
# 20821474      False      False    False      False  ...       False
#
#           cancel_vol_b  cancel_vol_s  cancel_val  cancel_val_b  cancel_val_s  \
# 0                False         False       False         False         False
# 1                False         False       False         False         False
# 2                False         False       False         False         False
# 3                False         False       False         False         False
# 4                False         False       False         False         False
# ...                ...           ...         ...           ...           ...
# 20821470         False         False       False         False         False
# 20821471         False         False       False         False         False
# 20821472         False         False       False         False         False
# 20821473         False         False       False         False         False
# 20821474         False         False       False         False         False
#
#           put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 0              False       False           True          False
# 1              False       False          False          False
# 2              False       False          False          False
# 3              False       False          False          False
# 4              False       False          False          False
# ...              ...         ...            ...            ...
# 20821470       False       False          False          False
# 20821471       False       False          False          False
# 20821472       False       False          False          False
# 20821473        True       False          False          False
# 20821474       False       False          False          False
#
# [20821475 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# secid                   98
# ts                       0
# put_orders               0
# put_orders_b             0
# put_orders_s             0
# put_vol                  0
# put_vol_b                0
# put_vol_s                0
# put_val                  0
# put_val_b                0
# put_val_s                0
# cancel_orders            0
# cancel_orders_b          0
# cancel_orders_s          0
# cancel_vol               0
# cancel_vol_b             0
# cancel_vol_s             0
# cancel_val               0
# cancel_val_b             0
# cancel_val_s             0
# put_vwap_b         1826227
# put_vwap_s         2454752
# cancel_vwap_b      3332227
# cancel_vwap_s      4054667
# dtype: int64

# %%
100 * df.isnull().sum() / len(df)
# Out:
# secid               0.000471
# ts                  0.000000
# put_orders          0.000000
# put_orders_b        0.000000
# put_orders_s        0.000000
# put_vol             0.000000
# put_vol_b           0.000000
# put_vol_s           0.000000
# put_val             0.000000
# put_val_b           0.000000
# put_val_s           0.000000
# cancel_orders       0.000000
# cancel_orders_b     0.000000
# cancel_orders_s     0.000000
# cancel_vol          0.000000
# cancel_vol_b        0.000000
# cancel_vol_s        0.000000
# cancel_val          0.000000
# cancel_val_b        0.000000
# cancel_val_s        0.000000
# put_vwap_b          8.770882
# put_vwap_s         11.789520
# cancel_vwap_b      16.003799
# cancel_vwap_s      19.473486
# dtype: float64

# %%
def percent_missing(my_df):
    result = 100 * my_df.isnull().sum() / len(my_df)
    result = result[result>0].sort_values()

    return result

# %%
percent_nan = percent_missing(df)

# %%
percent_nan
# Out:
# secid             0.000471
# put_vwap_b        8.770882
# put_vwap_s       11.789520
# cancel_vwap_b    16.003799
# cancel_vwap_s    19.473486
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation=90)
# plt.ylim(0,1)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'secid'),
#   Text(1, 0, 'put_vwap_b'),
#   Text(2, 0, 'put_vwap_s'),
#   Text(3, 0, 'cancel_vwap_b'),
#   Text(4, 0, 'cancel_vwap_s')])

# %%
df[df['secid'].isnull()]
# Out:
#          secid                   ts  put_orders  put_orders_b  put_orders_s  \
# 20311865   NaN  2023-10-19 10:05:00         114            61            53
# 20312107   NaN  2023-10-19 10:10:00         902           834            68
# 20312349   NaN  2023-10-19 10:15:00        1202          1095           107
# 20312591   NaN  2023-10-19 10:20:00        1072           989            83
# 20312833   NaN  2023-10-19 10:25:00        1048           948           100
# ...        ...                  ...         ...           ...           ...
# 20333862   NaN  2023-10-19 17:50:00         167            89            78
# 20334092   NaN  2023-10-19 17:55:00         163            85            78
# 20334323   NaN  2023-10-19 18:00:00         167            86            81
# 20334557   NaN  2023-10-19 18:05:00         170            88            82
# 20334790   NaN  2023-10-19 18:10:00         119            65            54
#
#           put_vol  put_vol_b  put_vol_s      put_val    put_val_b  ...  \
# 20311865      394          0          0    5413060.0    3320555.0  ...
# 20312107     8323          8          0  127738955.0  126294660.0  ...
# 20312349    10688         10          0  164114150.0  162330175.0  ...
# 20312591     9927          9          0  152441775.0  151161985.0  ...
# 20312833     9837          9          0  151142785.0  149596475.0  ...
# ...           ...        ...        ...          ...          ...  ...
# 20333862     1434          0          1   22641650.0    4160865.0  ...
# 20334092     1421          0          1   22435225.0    4098970.0  ...
# 20334323     1466          0          1   23155570.0    4129580.0  ...
# 20334557     1479          0          1   23355155.0    4224250.0  ...
# 20334790      973          0          0   15357235.0    3205785.0  ...
#
#           cancel_vol  cancel_vol_b  cancel_vol_s   cancel_val  cancel_val_b  \
# 20311865          39             0             0     596635.0      441125.0
# 20312107        8225             8             0  126226625.0   125058280.0
# 20312349       10680            10             0  163994355.0   162183040.0
# 20312591        9899             9             0  152015795.0   150793815.0
# 20312833        9829             9             0  151020230.0   149474060.0
# ...              ...           ...           ...          ...           ...
# 20333862        1433             0             1   22625115.0     4130250.0
# 20334092        1422             0             1   22453795.0     4098970.0
# 20334323        1447             0             1   22848075.0     4130240.0
# 20334557        1479             0             1   23351670.0     4223590.0
# 20334790         963             0             0   15199780.0     3032180.0
#
#           cancel_val_s  put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 20311865      155510.0   12074.745   17584.076      15211.207      15551.000
# 20312107     1168345.0   15343.781   15698.859      15344.574      15577.933
# 20312349     1811315.0   15353.275   15512.826      15353.881      15481.325
# 20312591     1221980.0   15355.748   15419.157      15355.786      15468.101
# 20312833     1546170.0   15363.713   15463.100      15363.764      15461.700
# ...                ...         ...         ...            ...            ...
# 20333862    18494865.0   15642.350   15822.590      15644.886      15821.099
# 20334092    18354825.0   15644.924   15820.755      15644.924      15823.125
# 20334323    18717835.0   15642.348   15828.611      15644.848      15822.346
# 20334557    19128080.0   15645.370   15823.743      15642.926      15821.406
# 20334790    12167600.0   15637.976   15822.201      15629.794      15822.627
#
# [98 rows x 24 columns]

# %%
df = df.dropna(axis=0, subset=['secid'])

# %%
df[df['secid'].isnull()]
# Out:
# Empty DataFrame
# Columns: [secid, ts, put_orders, put_orders_b, put_orders_s, put_vol, put_vol_b, put_vol_s, put_val, put_val_b, put_val_s, cancel_orders, cancel_orders_b, cancel_orders_s, cancel_vol, cancel_vol_b, cancel_vol_s, cancel_val, cancel_val_b, cancel_val_s, put_vwap_b, put_vwap_s, cancel_vwap_b, cancel_vwap_s]
# Index: []
#
# [0 rows x 24 columns]

# %%
percent_nan = percent_missing(df)

# %%
percent_nan
# Out:
# put_vwap_b        8.770923
# put_vwap_s       11.789561
# cancel_vwap_b    16.003869
# cancel_vwap_s    19.473558
# dtype: float64

# %%
df[df['put_vwap_b'].isnull()]
# Out:
#           secid                   ts  put_orders  put_orders_b  put_orders_s  \
# 311       KGKCP  2020-01-03 10:10:00           3             0             3
# 312        KLSB  2020-01-03 10:10:00           6             0             6
# 392        PRMB  2020-01-03 10:10:00           1             0             1
# 409        RTGZ  2020-01-03 10:10:00           0             0             0
# 537        IGST  2020-01-03 10:15:00           4             0             4
# ...         ...                  ...         ...           ...           ...
# 20821448   URKZ  2023-11-30 18:40:00           0             0             0
# 20821461   VSYD  2023-11-30 18:40:00          77             0            77
# 20821462  VSYDP  2023-11-30 18:40:00           4             0             4
# 20821465  WTCMP  2023-11-30 18:40:00           2             0             2
# 20821473   ZILL  2023-11-30 18:40:00          85             0            85
#
#           put_vol  put_vol_b  put_vol_s    put_val  put_val_b  ...  \
# 311            19          0         19    13390.0        0.0  ...
# 312           211          0        211   301846.0        0.0  ...
# 392             1          0          1    16800.0        0.0  ...
# 409             0          0          0        0.0        0.0  ...
# 537             5          0          5     5275.0        0.0  ...
# ...           ...        ...        ...        ...        ...  ...
# 20821448        0          0          0        0.0        0.0  ...
# 20821461      298          0        298  4885650.0        0.0  ...
# 20821462        7          0          7    91960.0        0.0  ...
# 20821465        2          0          2       20.0        0.0  ...
# 20821473     1934          0       1934  6555475.0        0.0  ...
#
#           cancel_vol  cancel_vol_b  cancel_vol_s  cancel_val  cancel_val_b  \
# 311                0             0             0         0.0           0.0
# 312                0             0             0         0.0           0.0
# 392                1             0             1     14600.0           0.0
# 409               25            25             0    415000.0      415000.0
# 537                8             8             0      6992.0        6992.0
# ...              ...           ...           ...         ...           ...
# 20821448           2             1             1     58250.0       28650.0
# 20821461         309             4           305   5063750.0       63000.0
# 20821462          12             0            12    157540.0           0.0
# 20821465          33             0            33       331.0           0.0
# 20821473        1935             2          1933   6559660.0        6490.0
#
#           cancel_val_s  put_vwap_b  put_vwap_s  cancel_vwap_b  cancel_vwap_s
# 311                0.0         NaN       70.50            NaN            NaN
# 312                0.0         NaN       14.31            NaN            NaN
# 392            14600.0         NaN    16800.00            NaN        14600.0
# 409                0.0         NaN         NaN        16600.0            NaN
# 537                0.0         NaN     1055.00          874.0            NaN
# ...                ...         ...         ...            ...            ...
# 20821448       28650.0         NaN         NaN        28650.0        29600.0
# 20821461       63000.0         NaN    16394.80        15750.0        16395.9
# 20821462           0.0         NaN    13137.10            NaN        13128.3
# 20821465           0.0         NaN        0.10            NaN            0.1
# 20821473        6490.0         NaN     3389.60         3245.0         3390.2
#
# [1826227 rows x 24 columns]
